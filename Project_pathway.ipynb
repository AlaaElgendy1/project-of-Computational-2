# %%
import cobra
from cobra import Model,Reaction,Metabolite

# %%
model=Model('e_coli')

# %%
ACONTa=Reaction('ACONTa') ##### cit_c ⇌ acon_C_c + h2o_c
ACONTa.name='Aconitase (half-reaction A, Citrate hydro-lyase)'
ACONTa.lower_bound=-1000
ACONTa.upper_bound=1000

ACONTb=Reaction('ACONTb') ##### acon_C_c + h2o_c ⇌ icit_c
ACONTb.name='Aconitase (half-reaction B, Isocitrate hydro-lyase)'
ACONTb.lower_bound=-1000
ACONTb.upper_bound=1000

AKGDH=Reaction('AKGDH') ##### akg_c + coa_c + nad_c ⇌ co2_c + nadh_c + succoa_c
AKGDH.name='2-Oxogluterate dehydrogenase'
AKGDH.lower_bound=0
AKGDH.upper_bound=1000

ATPM=Reaction('ATPM') ##### atp_c + h2o_c ⇌ adp_c + h_c + pi_c
ATPM.name='ATP maintenance requirement'
ATPM.lower_bound=8.39
ATPM.upper_bound=1000

ATPS4r=Reaction('ATPS4r') ##### adp_c + pi_c + 4.0 h_e ⇌ atp_c + 3.0 h_c + h2o_c
ATPS4r.name='ATP synthase (four protons for one ATP)'
ATPS4r.lower_bound=-1000
ATPS4r.upper_bound=1000

BIOMASS_Ecoli=Reaction('BIOMASS_Ecoli') ##### 1.496 3pg_c + 3.7478 accoa_c + 59.81 atp_c + 0.361 e4p_c + 0.0709 βF6P + 0.129 g3p_c + 0.205 g6p_c + 0.2557 gln__L_c + 4.9414 glu__L_c + 59.81 h2o_c + 3.547 nad_c + 13.0279 nadph_c + 1.7867 oaa_c + 0.5191 pep_c + 2.8328 pyr_c + 0.8977 r5p_c ⇌ 59.81 adp_c + 4.1182 akg_c + 3.7478 coa_c + 59.81 h_c + 3.547 nadh_c + 13.0279 nadp_c + 59.81 pi_c
BIOMASS_Ecoli.name='Biomass Objective Function with GAM'
BIOMASS_Ecoli.lower_bound=0
BIOMASS_Ecoli.upper_bound=1000

CO2t=Reaction('CO2t') ##### co2_e ⇌ co2_c
CO2t.name='CO2 transporter via diffusion'
CO2t.lower_bound=-1000
CO2t.upper_bound=1000

CS=Reaction('CS') ##### accoa_c + h2o_c + oaa_c ⇌ cit_c + coa_c + h_c
CS.name='Citrate synthase'
CS.lower_bound=0
CS.upper_bound=1000

CYTBD=Reaction('CYTBD') ##### 2.0 h_c + 0.5 o2_c + q8h2_c ⇌ h2o_c + q8_c + 2.0 h_e
CYTBD.name='Cytochrome oxidase bd (ubiquinol-8: 2 protons)'
CYTBD.lower_bound=0
CYTBD.upper_bound=1000

ENO=Reaction('ENO') ##### 2pg_c ⇌ h2o_c + pep_c
ENO.name='Enolase'
ENO.lower_bound=-1000
ENO.upper_bound=1000

EX_co2=Reaction('EX_co2') ##### co2_e ⇌
EX_co2.name='CO2 exchange'
EX_co2.lower_bound=-1000
EX_co2.upper_bound=1000

EX_glc_D=Reaction('EX_glc_D') ##### glc__D_e ⇌
EX_glc_D.name='D-Glucose exchange'
EX_glc_D.lower_bound=-10
EX_glc_D.upper_bound=1000

EX_h=Reaction('EX_h') ##### h_e ⇌
EX_h.name='H+ exchange'
EX_h.lower_bound=-1000
EX_h.upper_bound=1000

EX_h2o=Reaction('EX_h2o') ##### h2o_e ⇌
EX_h2o.name='H2O exchange'
EX_h2o.lower_bound=-1000
EX_h2o.upper_bound=1000

EX_nh4=Reaction('EX_nh4') ##### nh4_e ⇌    ## Ammonium
EX_nh4.name='Ammonia exchange'
EX_nh4.lower_bound=-1000
EX_nh4.upper_bound=1000

EX_o2=Reaction('EX_o2') ##### o2_e ⇌
EX_o2.name='O2 exchange'
EX_o2.lower_bound=-1000
EX_o2.upper_bound=1000

EX_pi=Reaction('EX_pi') ##### pi_e ⇌
EX_pi.name='Phosphate exchange'
EX_pi.lower_bound=-1000
EX_pi.upper_bound=1000

FBA=Reaction('FBA')########## FDP <=============> DHAP + G3P
FBA.name='Fructose-bisphosphate aldolase'
FBA.lower_bound=-1000
FBA.upper_bound=1000

FUM=Reaction('FUM')########## fum_c + h2o_c ⇌ mal__L_c
FUM.name='Fumarase'
FUM.lower_bound=-1000
FUM.upper_bound=1000

G6PDH2r=Reaction('G6PDH2r')########## g6p_c + nadp_c ⇌ 6pgl_c + h_c + nadph_c
G6PDH2r.name='Glucose 6-phosphate dehydrogenase'
G6PDH2r.lower_bound=-1000
G6PDH2r.upper_bound=1000

GAPD=Reaction('GAPD')########## G3P + NAD + Pi <==========> DPG13 + NADH + H+
GAPD.name='Glyceraldehyde 3-phosphate dehydrogenase'
GAPD.lower_bound=-1000
GAPD.upper_bound=1000

GLCpts=Reaction('GLCpts')########## pep_c + glc__D_e ⇌ g6p_c + pyr_c
GLCpts.name='D-glucose transport via PEP:Pyr PTS'
GLCpts.lower_bound=0
GLCpts.upper_bound=1000

GLNS=Reaction('GLNS')########## atp_c + glu__L_c + nh4_c ⇌ adp_c + gln__L_c + h_c + pi_c
GLNS.name='Glutamine synthetase'
GLNS.lower_bound=0
GLNS.upper_bound=1000

GLUDy=Reaction('GLUDy')########## glu__L_c + h2o_c + nadp_c ⇌ akg_c + h_c + nadph_c + nh4_c
GLUDy.name='Glutamate dehydrogenase (NADP)'
GLUDy.lower_bound=-1000
GLUDy.upper_bound=1000

GND=Reaction('GND')########## 6pgc_c + nadp_c ⇌ co2_c + nadph_c + ru5p__D_c
GND.name='Phosphogluconate dehydrogenase'
GND.lower_bound=0
GND.upper_bound=1000

H2Ot=Reaction('H2Ot')########## h2o_e ⇌ h2o_c
H2Ot.name='H2O transport via diffusion'
H2Ot.lower_bound=-1000
H2Ot.upper_bound=1000

ICDHyr=Reaction('ICDHyr')########## icit_c + nadp_c ⇌ akg_c + co2_c + nadph_c
ICDHyr.name='Isocitrate dehydrogenase (NADP)'
ICDHyr.lower_bound=-1000
ICDHyr.upper_bound=1000

MDH=Reaction('MDH')########## mal__L_c + nad_c ⇌ h_c + nadh_c + oaa_c
MDH.name='Malate dehydrogenase'
MDH.lower_bound=-1000
MDH.upper_bound=1000

NADH16=Reaction('NADH16')########## 4.0 h_c + nadh_c + q8_c ⇌ nad_c + q8h2_c + 3.0 h_e
NADH16.name='NADH dehydrogenase (ubiquinone-8 & 3 protons)'
NADH16.lower_bound=0
NADH16.upper_bound=1000

NH4t=Reaction('NH4t')########## nh4_e ⇌ nh4_c
NH4t.name='Ammonia reversible transport'
NH4t.lower_bound=-1000
NH4t.upper_bound=1000

O2t=Reaction('O2t')########## o2_e ⇌ o2_c
O2t.name='O2 transport  diffusion'
O2t.lower_bound=-1000
O2t.upper_bound=1000

PDH=Reaction('PDH')########## coa_c + nad_c + pyr_c ⇌ accoa_c + co2_c + nadh_c
PDH.name='Pyruvate dehydrogenase'
PDH.lower_bound=0
PDH.upper_bound=1000

PFK=Reaction('PFK')########## F6P + ATP ========> FDP + ADP + H
PFK.name='Phosphofructokinase'
PFK.lower_bound=0
PFK.upper_bound=1000

PGI=Reaction('PGI')########## G6P <===========> F6P
PGI.name='Glucose 6-phosphate isomerase'
PGI.lower_bound=-1000
PGI.upper_bound=1000

PGK=Reaction('PGK')########## DPG13 + ADP <=============> PG3 + ATP
PGK.name='Phosphoglycerate kinase'
PGK.lower_bound=-1000
PGK.upper_bound=1000

PGL=Reaction('PGL')########## 6pgl_c + h2o_c ⇌ 6pgc_c + h_c
PGL.name='6-phosphogluconolactonase'
PGL.lower_bound=0
PGL.upper_bound=1000

PGM=Reaction('PGM')########## PG3 <===========> PG2
PGM.name='Phosphoglycerate mutase'
PGM.lower_bound=-1000
PGM.upper_bound=1000

PIt2r=Reaction('PIt2r')########## h_e + pi_e ⇌ h_c + pi_c
PIt2r.name='Phosphate reversible transport via symport'
PIt2r.lower_bound=-1000
PIt2r.upper_bound=1000

PPC=Reaction('PPC')########## co2_c + h2o_c + pep_c ⇌ h_c + oaa_c + pi_c
PPC.name='Phosphoenolpyruvate carboxylase'
PPC.lower_bound=0
PPC.upper_bound=1000

PYK=Reaction('PYK')########## PEP + ADP + H+ =======> PYR + ATP
PYK.name='Pyruvate kinase'
PYK.lower_bound=0
PYK.upper_bound=1000

RPE=Reaction('RPE')########## ru5p__D_c ⇌ xu5p__D_c
RPE.name='Ribulose 5-phosphate 3-epimerase'
RPE.lower_bound=-1000
RPE.upper_bound=1000

RPI=Reaction('RPI')########## r5p_c ⇌ ru5p__D_c
RPI.name='Ribose-5-phosphate isomerase'
RPI.lower_bound=-1000
RPI.upper_bound=1000

SUCDi=Reaction('SUCDi')########## q8_c + succ_c ⇌ fum_c + q8h2_c
SUCDi.name='Succinate dehydrogenase (irreversible)'
SUCDi.lower_bound=0
SUCDi.upper_bound=1000

SUCOAS=Reaction('SUCOAS')########## atp_c + coa_c + succ_c ⇌ adp_c + pi_c + succoa_c
SUCOAS.name='Succinyl-CoA synthetase (ADP-forming)'
SUCOAS.lower_bound=-1000
SUCOAS.upper_bound=1000

TALA=Reaction('TALA')########## g3p_c + s7p_c ⇌ e4p_c + f6p_c
TALA.name='Transaldolase'
TALA.lower_bound=-1000
TALA.upper_bound=1000

TKT1=Reaction('TKT1')########## r5p_c + xu5p__D_c ⇌ g3p_c + s7p_c
TKT1.name='Transketolase'
TKT1.lower_bound=-1000
TKT1.upper_bound=1000

TKT2=Reaction('TKT2')########## e4p_c + xu5p__D_c ⇌ f6p_c + g3p_c
TKT2.name='Transketolase'
TKT2.lower_bound=-1000
TKT2.upper_bound=1000

TPI=Reaction('TPI')########## dhap_c ⇌ g3p_c
TPI.name='Triose-phosphate isomerase'
TPI.lower_bound=-1000
TPI.upper_bound=1000

# %%
citrate=Metabolite('citrate',formula='C6H5O7',name='Citrate',compartment='c')

acon_C_c=Metabolite('acon_C_c',formula='C6H3O6',name='Cis-Aconitate', compartment='c')

h2o_c=Metabolite('h2o_c',formula='H2O',name='H2O H2O', compartment='c')

h2o_e=Metabolite('h2o_e',formula='H2O',name='H2O H2O',compartment='e')

#icit_c
Dthreoisocitrate=Metabolite('Dthreoisocitrate',formula='C6H5O7',name='Isocitrate',compartment='c')

#akg_c
oxoglutarate=Metabolite('oxoglutarate',formula='C5H4O5',name='2-Oxoglutarate',compartment='c')

#coa_c
CoA=Metabolite('CoA',formula='C21H32N7O16P3S',name='Coenzyme A',compartment='c')

#NAD
NAD=Metabolite('NAD',formula='C21H26N7O14P2',name='Nicotinamide adenine dinucleotide',compartment='c')

co2_c=Metabolite('co2_c',formula='CO2',name='CO2 CO2',compartment='c')

co2_e=Metabolite('co2_e',formula='CO2',name='CO2 CO2',compartment='e')

#nadh_c
NADH=Metabolite('NADH',formula='C21H27N7O14P2',name='Nicotinamide adenine dinucleotide - reduced',compartment='c')

#succoa_c
succinylCoA=Metabolite('succinylCoA',formula='C25H35N7O19P3S',name='Succinyl-CoA',compartment='c')

#atp_c
ATP=Metabolite('ATP',formula='C10H12N5O13P3',name='ATP C10H12N5O13P3',compartment='c')

#adp_c
ADP=Metabolite('ADP',formula='C10H12N5O10P2',name='ADP C10H12N5O10P2',compartment='c')

#h_c
H=Metabolite('H',formula='H',name='H+',compartment='c')

#pi_c
phosphate=Metabolite('phosphate',formula='HO4P',name='Phosphate',compartment='c')

pi_e=Metabolite('pi_e',formula='HO4P',name='Phosphate',compartment='e')

h_e=Metabolite('h_e',formula='H',name='H+',compartment='e')

m_3pg_c=Metabolite('m_3pg_c', formula='C3H4O7P',name='3-Phospho-D-glycerate',compartment='c')

#acetylCoA
acetylCoA=Metabolite('acetylCoA',formula='C23H34N7O17P3S',name='Acetyl-CoA',compartment='c')

e4p_c=Metabolite('e4p_c',formula='C4H7O7P',name='D-Erythrose 4-phosphate',compartment='c')

#f6p_c
βF6P=Metabolite('βF6P',formula='C6H11O9P',name='D-Fructose 6-phosphate',compartment='c')

#g3p_c
G3P=Metabolite('G3P',formula='C3H5O6P',name='Glyceraldehyde 3-phosphate',compartment='c')

#g6p_c
DG6P=Metabolite('DG6P',formula='C6H11O9P',name='D-Glucose 6-phosphate',compartment='c')

#gln__L_c
L_Glutamine=Metabolite('L_Glutamine',formula='C5H10N2O3',name='L-Glutamine',compartment='c')

#glu__L_c
L_Glutamate=Metabolite('L_Glutamate',formula='C5H8NO4',name='L-Glutamate',compartment='c')

#nadph_c
NADPH=Metabolite('NADPH',formula='C21H26N7O17P3',name='Nicotinamide adenine dinucleotide phosphate - reduced',compartment='c')

#oaa_c
oxaloacetate=Metabolite('oxaloacetate',formula='C4H2O5',name='Oxaloacetate',compartment='c')

#pep_c
PPyruv=Metabolite('PPyruv',formula='C3H2O6P',name='Phosphoenolpyruvate',compartment='c')

#pyr_c
pyruvate=Metabolite('pyruvate',formula='C3H3O3',name='Pyruvate',compartment='c')

r5p_c=Metabolite('r5p_c',formula='C5H9O8P',name='Alpha-D-Ribose 5-phosphate', compartment='c')

nadp_c=Metabolite('nadp_c',formula='C21H25N7O17P3',name='Nicotinamide adenine dinucleotide phosphate',compartment='c')

o2_c=Metabolite('o2_c',formula='O2',name='O2 O2',compartment='c')

o2_e=Metabolite('o2_e',formula='O2', name='O2 O2', compartment='e')

q8h2_c=Metabolite('q8h2_c',formula='C49H76O4',name='Ubiquinol-8',compartment='c')

q8_c=Metabolite('q8_c',formula='C49H74O4',name='Ubiquinone-8',compartment='c')

m_2pg_c=Metabolite('m_2pg_c', formula='C3H4O7P',name='D-Glycerate 2-phosphate',compartment='c')

glc__D_e=Metabolite('glc__D_e',formula='C6H12O6',name='D-Glucose',compartment='e')

nh4_e=Metabolite('nh4_e',formula='H4N',name='Ammonium',compartment='e')

nh4_c=Metabolite('nh4_c',formula='H4N',name='Ammonium',compartment='c')

#fdp_c
βF16P=Metabolite('βF16P',formula='C6H10O12P2',name='c',compartment='c')

#dhap_c
dihydroxph=Metabolite('dihydroxph',formula='C3H5O6P',name='Dihydroxyacetone phosphate',compartment='c')

#fum_c
fumarate=Metabolite('fumarate', formula='C4H2O4',name='Fumarate',compartment='c')

mal__L_c=Metabolite('mal__L_c',formula='C4H4O5',name='L-Malate',compartment='c')

m_6pgl_c=Metabolite('m_6pgl_c',formula='C6H9O9P',name='6-phospho-D-glucono-1,5-lactone',compartment='c')

m_13dpg_c=Metabolite('m_13dpg_c',formula='C3H4O10P2',name='3-Phospho-D-glyceroyl phosphate', compartment='c')

#m_6pgc_c
PDG6=Metabolite('PDG6',formula='C6H10O10P',name='6-Phospho-D-gluconate',compartment='c')

#ru5p__D_c
DR5P=Metabolite('DR5P',formula='C5H9O8P',name='D-Ribulose 5-phosphate',compartment='c')

#xu5p__D_c
DX5P=Metabolite('DX5P',formula='C5H9O8P',name='D-Xylulose 5-phosphate',compartment='c')

#succ_c
succinate=Metabolite('succinate',formula='C4H4O4',name='Succinate',compartment='c')

#s7p_c
DS7P=Metabolite('DS7P',formula='C7H13O10P',name='Sedoheptulose 7-phosphate',compartment='c')

# %%
ACONTa.add_metabolites({citrate:-1,acon_C_c:1,h2o_c:1})

ACONTb.add_metabolites({acon_C_c:-1,h2o_c:-1,Dthreoisocitrate:1})

AKGDH.add_metabolites({oxoglutarate:-1,CoA:-1,NAD:-1,co2_c:1,NADH:1,succinylCoA:1})

ATPM.add_metabolites({ATP:-1,h2o_c:-1, ADP:1,H:1,phosphate:1})

ATPS4r.add_metabolites({ADP:-1,phosphate:-1,h_e:-4,ATP:1,H:3,h2o_c:1})

BIOMASS_Ecoli.add_metabolites({m_3pg_c:-1.496,acetylCoA:-3.7478,ATP:-59.81,e4p_c:-0.361,βF6P:-0.0709,G3P:-0.129,DG6P:-0.205,L_Glutamine:-0.2557,L_Glutamate:-4.9414,h2o_c:-59.81,NAD:-3.547,NADPH:-13.0279,oxaloacetate:-1.7867,PPyruv:-0.5191,pyruvate:-2.8328,r5p_c:-0.8977,ADP:59.81,oxoglutarate:4.1182,CoA:3.7478,H:59.81,NADH:3.547,nadp_c:13.0279,phosphate:59.81})

CO2t.add_metabolites({co2_e:-1,co2_c:1})

CS.add_metabolites({acetylCoA:-1,h2o_c:-1,oxaloacetate:-1,citrate:1,CoA:1,H:1})

CYTBD.add_metabolites({H:-2,o2_c:-0.5,q8h2_c:-1,h2o_c:1,q8_c:1,h_e:2})

ENO.add_metabolites({m_2pg_c:-1,h2o_c:1,PPyruv:1})

EX_co2.add_metabolites({co2_e:-1})

EX_glc_D.add_metabolites({glc__D_e:-1})

EX_h.add_metabolites({h_e:-1})

EX_h2o.add_metabolites({h2o_e:-1})

EX_nh4.add_metabolites({nh4_e:-1})

EX_o2.add_metabolites({o2_e:-1})

EX_pi.add_metabolites({pi_e:-1})

FBA.add_metabolites({βF16P:-1,dihydroxph:1,G3P:1})

FUM.add_metabolites({fumarate:-1,h2o_c:-1,mal__L_c:1})

G6PDH2r.add_metabolites({DG6P:-1,nadp_c:-1,m_6pgl_c:1,H:1,NADPH:1})

GAPD.add_metabolites({G3P:-1,NAD:-1,phosphate:-1,m_13dpg_c:1,H:1,NADH:1})

GLCpts.add_metabolites({PPyruv:-1,glc__D_e:-1,DG6P:1,pyruvate:1})

GLNS.add_metabolites({ATP:-1,L_Glutamate:-1,nh4_c:-1,ADP:1,L_Glutamine:1,H:1,phosphate:1})

GLUDy.add_metabolites({L_Glutamate:-1,h2o_c:-1,nadp_c:-1,oxoglutarate:1,H:1,NADPH:1,nh4_c:1})

GND.add_metabolites({PDG6:-1,nadp_c:-1,co2_c:1,NADPH:1,DR5P:1})

H2Ot.add_metabolites({h2o_e:-1,h2o_c:1})

ICDHyr.add_metabolites({Dthreoisocitrate:-1,nadp_c:-1,oxoglutarate:1,co2_c:1,NADPH:1})

MDH.add_metabolites({mal__L_c:-1,NAD:-1,H:1,NADH:1,oxaloacetate:1})

NADH16.add_metabolites({H:-4,NADH:-1,q8_c:-1,NAD:1,q8h2_c:1,h_e:3})

NH4t.add_metabolites({nh4_e:-1,nh4_c:1})

O2t.add_metabolites({o2_e:-1,o2_c:1})

PDH.add_metabolites({CoA:-1,NAD:-1,pyruvate:-1,acetylCoA:1,co2_c:1,NADH:1})

PFK.add_metabolites({ATP:-1,βF6P:-1,ADP:1,βF16P:1,H:1})

PGI.add_metabolites({DG6P:-1,βF6P:1})

PGK.add_metabolites({m_3pg_c:-1,ATP:-1,m_13dpg_c:1,ADP:1})

PGL.add_metabolites({m_6pgl_c:-1,h2o_c:-1,PDG6:1,H:1})

PGM.add_metabolites({m_2pg_c:-1,m_3pg_c:1})

PIt2r.add_metabolites({h_e:-1,pi_e:-1,H:1,phosphate:1})

PPC.add_metabolites({co2_c:-1,h2o_c:-1,PPyruv:-1,H:1,oxaloacetate:1,phosphate:1})

PYK.add_metabolites({ADP:-1,H:-1,PPyruv:-1,ATP:1,pyruvate:1})

RPE.add_metabolites({DR5P:-1,DX5P:1})

RPI.add_metabolites({r5p_c:-1,DR5P:1})

SUCDi.add_metabolites({q8_c:-1,succinate:-1,fumarate:1,q8h2_c:1})

SUCOAS.add_metabolites({ATP:-1,CoA:-1,succinate:-1,ADP:1,phosphate:1,succinylCoA:1})

TALA.add_metabolites({G3P:-1,DS7P:-1,e4p_c:1,βF6P:1})

TKT1.add_metabolites({r5p_c:-1,DX5P:-1,G3P:1,DS7P:1})

TKT2.add_metabolites({e4p_c:-1,DX5P:-1,βF6P:1,G3P:1})

TPI.add_metabolites({dihydroxph:-1,G3P:1})

# %%
model.add_reactions({ACONTa,ACONTb,AKGDH,ATPM,ATPS4r,BIOMASS_Ecoli,CO2t,CS,CYTBD,ENO,EX_co2,EX_glc_D,EX_h,EX_h2o,EX_nh4,EX_o2,EX_pi,FBA,FUM,G6PDH2r,GAPD,GLCpts,GLNS,GLUDy,GND,H2Ot,ICDHyr,MDH,NADH16,NH4t,O2t,PDH,PFK,PGI,PGK,PGL,PGM,PIt2r,PPC,PYK,RPE,RPI,SUCDi,SUCOAS,TALA,TKT1,TKT2,TPI})

# %%
model.objective='BIOMASS_Ecoli'

# %%
model.optimize()
# Out:
# <Solution 0.874 at 0x1d9d2568df0>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli = 0.8739215069684295</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc_D</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
# ...

# %%
cobra.io.save_json_model(model,"test4.json")

# %%
import escher

# %%
from escher import Builder

# %%
cobra.io.load_json_model("test4.json")
# Out:
# <Model e_coli at 0x1d9d2bf4040>

# %%
builder = Builder(model_json="test4.json")

# %%
builder
# Out:
# Builder()

# %%
sol=model.optimize()
builder.reaction_data=sol.fluxes
